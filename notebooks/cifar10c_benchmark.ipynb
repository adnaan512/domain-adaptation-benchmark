# %% [markdown]
# # Domain Adaptation Benchmark — Test-Time Adaptation
#
# This notebook evaluates **Test-Time Adaptation (TTA)** strategies to handle distribution shift in deep learning models, using the CIFAR-10-C dataset.
#
# It runs the official benchmark pipeline from the [Domain Adaptation Benchmark](https://github.com/adnaan512/domain-adaptation-benchmark) repository.
#
# ### Instructions
# 1. Ensure the **Accelerator** is set to **GPU T4 x2** (or P100) on the right panel.
# 2. (Optional) Attach your clean `cifar-10-python` dataset and the raw `CIFAR-10-C.tar` file as Kaggle Input Datasets to skip downloading.
# 3. Click **Run All**.

# %%
# 1. Clone the repository
# !git clone https://github.com/adnaan512/domain-adaptation-benchmark.git

# 2. Enter the directory
# %cd domain-adaptation-benchmark

# 3. Install requirements
# !pip install -r requirements.txt

# %%
# 4. Run the full benchmark pipeline
# !python notebooks/kaggle_benchmark.py

# %% [markdown]
# ## Results
#
# Once the execution finishes (approx. 30 minutes on GPU), the script will automatically generate:
# * `benchmark_report.html` — A full interactive dashboard with statistical significance tests.
# * `figures/` — A folder containing publication-quality graphs (Accuracy Heatmaps, Entropy Scatter Plots, etc.).
#
# You can download these from the **Output** tab on Kaggle.
